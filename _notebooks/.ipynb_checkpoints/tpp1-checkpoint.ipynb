# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import seaborn as sns

from scipy import stats
sns.set_style('ticks')
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 1.0})


# %matplotlib inline

# %%
colors =  plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
x = np.linspace(0, 2.5, 1000)
dist = stats.weibull_min(2.5, scale=1.0)
t = 0.7
dt = 0.11

# %%
fig, axes = plt.subplots(ncols=4, dpi=200, figsize=(13, 3))
axes[0].plot(x, dist.pdf(x), c=colors[0], linewidth=2.5)
axes[1].plot(x, dist.cdf(x), c=colors[1], linewidth=2.5)
axes[2].plot(x, dist.sf(x), c=colors[4], linewidth=2.5)
axes[3].plot(x, dist.pdf(x) / dist.sf(x), c=colors[3], linewidth=2.5)

# %%
fig = plt.figure(dpi=200)
ax = plt.gca()

p = dist.pdf(x)
# rect = patches.Rectangle((t, 0), dt, dist.pdf(t), linewidth=0, 
#                          facecolor=colors[1], alpha=0.7)
rect = patches.Polygon([[t, 0], 
                        [t + dt, 0], 
                        [t + dt, dist.pdf(t + dt)], 
                        [t + 0.5 * dt, dist.pdf(t + 0.5 * dt)], 
                        [t, dist.pdf(t)]],
                 facecolor=colors[1], alpha=0.8)
ax.add_patch(rect)
plt.plot(x, p, color=colors[0], linewidth=2.5)
locs, labels = plt.xticks(np.array([0, t, t + dt]), (r"$\quad t_{i-1}$", r"$t$", r"$\;\qquad t + dt$"))
ax.xaxis.grid(False)

plt.ylabel(r'$p^*(t)$')
plt.show()
# plt.xlabel(r'$t$')

# %%
fig = plt.figure(dpi=200)
ax = plt.gca()

p = dist.pdf(x)
plt.plot(x, p, color=colors[0], linewidth=2.5)
x_before = x[x < t]
x_dt = x[(x >= t) & (x < t + dt)]
x_after = x[x >= t + dt]

ax.fill_between(x_before, dist.pdf(x_before), 0, alpha=0.7)
ax.fill_between(x_dt, dist.pdf(x_dt), 0, alpha=0.7)
ax.fill_between(x_after, dist.pdf(x_after), 0, alpha=0.7)
locs, labels = plt.xticks(np.array([0, t, t + dt]), (r"$\quad t_{i-1}$", r"$t$", r"$\;\qquad t + dt$"))
ax.xaxis.grid(False)

plt.ylabel(r'$p^*(t)$')
plt.show()
# plt.xlabel(r'$t$')
